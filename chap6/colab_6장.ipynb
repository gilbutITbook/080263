# %%
#6.1.1 LeNet

# %%
# %load_ext tensorboard

import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Dropout

# %%
num_classes = 2
class LeNet(Sequential):
    def __init__(self, input_shape, nb_classes):
        super().__init__()

        self.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape, padding="same"))
        self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
        self.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))
        self.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
        self.add(Flatten())
        self.add(Dense(120, activation='relu'))
        self.add(Dense(84, activation='relu'))
        self.add(Dense(nb_classes, activation='softmax'))

        self.compile(optimizer='adam',
                    loss=categorical_crossentropy,
                    metrics=['accuracy'])

# %%
model = LeNet((100, 100, 3), num_classes)
model.summary()
# Out:
# Model: "le_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 6)       456
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 50, 50, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 23, 23, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8464)              0
# _________________________________________________________________
# dense (Dense)                (None, 120)               1015800
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 170
# =================================================================
# Total params: 1,029,006
# Trainable params: 1,029,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()   

#시간이 오래 걸리면 구글 드라이브에서 불러오기로 변경해서 진행해주세요.
#from google.colab import drive 
#drive.mount('/content/drive/') 

#chap5 > data 폴더에 있는 catanddog.zip 파일을 선택합니다.
train_dir = "catanddog.zip"
# !unzip catanddog.zip               #압축 풀기
# Out:
#      <input type="file" id="files-6c17902c-bf6d-4d1c-bf65-b810c495dbe4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c17902c-bf6d-4d1c-bf65-b810c495dbe4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving catanddog.zip to catanddog.zip
# Archive:  catanddog.zip
#    creating: train/
#    creating: train/Cat/
#   inflating: train/Cat/0.jpg
#   inflating: train/Cat/1.jpg
#   inflating: train/Cat/10.jpg
#   inflating: train/Cat/11.jpg
#   inflating: train/Cat/12.jpg
#   inflating: train/Cat/13.jpg
#   inflating: train/Cat/14.jpg
#   inflating: train/Cat/15.jpg
#   inflating: train/Cat/16.jpg
#   inflating: train/Cat/17.jpg
#   inflating: train/Cat/18.jpg
#   inflating: train/Cat/19.jpg
#   inflating: train/Cat/2.jpg
#   inflating: train/Cat/20.jpg
#   inflating: train/Cat/21.jpg
#   inflating: train/Cat/22.jpg
#   inflating: train/Cat/23.jpg
#   inflating: train/Cat/24.jpg
#   inflating: train/Cat/25.jpg
#   inflating: train/Cat/26.jpg
#   inflating: train/Cat/27.jpg
#   inflating: train/Cat/28.jpg
#   inflating: train/Cat/29.jpg
#   inflating: train/Cat/3.jpg
#   inflating: train/Cat/30.jpg
#   inflating: train/Cat/31.jpg
#   inflating: train/Cat/32.jpg
#   inflating: train/Cat/33.jpg
#   inflating: train/Cat/34.jpg
#   inflating: train/Cat/35.jpg
#   inflating: train/Cat/36.jpg
#   inflating: train/Cat/37.jpg
#   inflating: train/Cat/38.jpg
#   inflating: train/Cat/39.jpg
#   inflating: train/Cat/4.jpg
#   inflating: train/Cat/40.jpg
#   inflating: train/Cat/41.jpg
#   inflating: train/Cat/42.jpg
#   inflating: train/Cat/43.jpg
#   inflating: train/Cat/44.jpg
#   inflating: train/Cat/45.jpg
#   inflating: train/Cat/46.jpg
#   inflating: train/Cat/47.jpg
#   inflating: train/Cat/48.jpg
#   inflating: train/Cat/49.jpg
#   inflating: train/Cat/5.jpg
#   inflating: train/Cat/50.jpg
#   inflating: train/Cat/51.jpg
#   inflating: train/Cat/52.jpg
#   inflating: train/Cat/53.jpg
#   inflating: train/Cat/54.jpg
#   inflating: train/Cat/55.jpg
#   inflating: train/Cat/56.jpg
#   inflating: train/Cat/57.jpg
#   inflating: train/Cat/58.jpg
#   inflating: train/Cat/59.jpg
#   inflating: train/Cat/6.jpg
#   inflating: train/Cat/60.jpg
#   inflating: train/Cat/61.jpg
#   inflating: train/Cat/62.jpg
#   inflating: train/Cat/7.jpg
#   inflating: train/Cat/7539.jpg
#   inflating: train/Cat/7540.jpg
#   inflating: train/Cat/7541.jpg
#   inflating: train/Cat/7542.jpg
#   inflating: train/Cat/7543.jpg
#   inflating: train/Cat/7544.jpg
#   inflating: train/Cat/7545.jpg
#   inflating: train/Cat/7546.jpg
#   inflating: train/Cat/7547.jpg
#   inflating: train/Cat/7548.jpg
#   inflating: train/Cat/7549.jpg
#   inflating: train/Cat/7550.jpg
#   inflating: train/Cat/7551.jpg
#   inflating: train/Cat/7552.jpg
#   inflating: train/Cat/7553.jpg
#   inflating: train/Cat/7554.jpg
#   inflating: train/Cat/7555.jpg
#   inflating: train/Cat/7556.jpg
#   inflating: train/Cat/7557.jpg
#   inflating: train/Cat/7558.jpg
#   inflating: train/Cat/7559.jpg
#   inflating: train/Cat/7560.jpg
#   inflating: train/Cat/7561.jpg
#   inflating: train/Cat/7562.jpg
#   inflating: train/Cat/7563.jpg
#   inflating: train/Cat/7564.jpg
#   inflating: train/Cat/7565.jpg
#   inflating: train/Cat/7566.jpg
#   inflating: train/Cat/7567.jpg
#   inflating: train/Cat/7568.jpg
#   inflating: train/Cat/7569.jpg
#   inflating: train/Cat/7570.jpg
#   inflating: train/Cat/7571.jpg
#   inflating: train/Cat/7572.jpg
#   inflating: train/Cat/7573.jpg
#   inflating: train/Cat/7574.jpg
#   inflating: train/Cat/7575.jpg
#   inflating: train/Cat/7576.jpg
#   inflating: train/Cat/7577.jpg
#   inflating: train/Cat/7578.jpg
#   inflating: train/Cat/7579.jpg
#   inflating: train/Cat/7580.jpg
#   inflating: train/Cat/7581.jpg
#   inflating: train/Cat/7582.jpg
#   inflating: train/Cat/7583.jpg
#   inflating: train/Cat/7584.jpg
#   inflating: train/Cat/7585.jpg
#   inflating: train/Cat/7586.jpg
#   inflating: train/Cat/7587.jpg
#   inflating: train/Cat/7588.jpg
#   inflating: train/Cat/7589.jpg
#   inflating: train/Cat/7590.jpg
#   inflating: train/Cat/7591.jpg
#   inflating: train/Cat/7592.jpg
#   inflating: train/Cat/7593.jpg
#   inflating: train/Cat/7594.jpg
#   inflating: train/Cat/7595.jpg
#   inflating: train/Cat/7596.jpg
#   inflating: train/Cat/7597.jpg
#   inflating: train/Cat/7598.jpg
#   inflating: train/Cat/7599.jpg
#   inflating: train/Cat/7600.jpg
#   inflating: train/Cat/7601.jpg
#   inflating: train/Cat/7602.jpg
#   inflating: train/Cat/7603.jpg
#   inflating: train/Cat/7604.jpg
#   inflating: train/Cat/7605.jpg
#   inflating: train/Cat/7606.jpg
#   inflating: train/Cat/7607.jpg
#   inflating: train/Cat/7608.jpg
#   inflating: train/Cat/7609.jpg
#   inflating: train/Cat/7610.jpg
#   inflating: train/Cat/7611.jpg
#   inflating: train/Cat/7612.jpg
#   inflating: train/Cat/7613.jpg
#   inflating: train/Cat/7614.jpg
#   inflating: train/Cat/7615.jpg
#   inflating: train/Cat/7616.jpg
#   inflating: train/Cat/7617.jpg
#   inflating: train/Cat/7618.jpg
#   inflating: train/Cat/7619.jpg
#   inflating: train/Cat/7620.jpg
#   inflating: train/Cat/7621.jpg
#   inflating: train/Cat/7622.jpg
#   inflating: train/Cat/7623.jpg
#   inflating: train/Cat/7624.jpg
#   inflating: train/Cat/7625.jpg
#   inflating: train/Cat/7626.jpg
#   inflating: train/Cat/7627.jpg
#   inflating: train/Cat/7628.jpg
#   inflating: train/Cat/7629.jpg
#   inflating: train/Cat/7630.jpg
#   inflating: train/Cat/7631.jpg
#   inflating: train/Cat/7632.jpg
#   inflating: train/Cat/7633.jpg
#   inflating: train/Cat/7634.jpg
#   inflating: train/Cat/7635.jpg
#   inflating: train/Cat/7636.jpg
#   inflating: train/Cat/7637.jpg
#   inflating: train/Cat/7638.jpg
#   inflating: train/Cat/7639.jpg
#   inflating: train/Cat/7640.jpg
#   inflating: train/Cat/7641.jpg
#   inflating: train/Cat/7642.jpg
#   inflating: train/Cat/7643.jpg
#   inflating: train/Cat/7644.jpg
#   inflating: train/Cat/7645.jpg
#   inflating: train/Cat/7646.jpg
#   inflating: train/Cat/7647.jpg
#   inflating: train/Cat/7648.jpg
#   inflating: train/Cat/7649.jpg
#   inflating: train/Cat/7650.jpg
#   inflating: train/Cat/7651.jpg
#   inflating: train/Cat/7652.jpg
#   inflating: train/Cat/7653.jpg
#   inflating: train/Cat/7654.jpg
#   inflating: train/Cat/7655.jpg
#   inflating: train/Cat/7656.jpg
#   inflating: train/Cat/7657.jpg
#   inflating: train/Cat/8.jpg
#   inflating: train/Cat/9.jpg
#    creating: train/Dog/
#   inflating: train/Dog/0.jpg
#   inflating: train/Dog/1.jpg
#   inflating: train/Dog/10.jpg
#   inflating: train/Dog/1000.jpg
#   inflating: train/Dog/1001.jpg
#   inflating: train/Dog/1002.jpg
#   inflating: train/Dog/1003.jpg
#   inflating: train/Dog/1004.jpg
#   inflating: train/Dog/1005.jpg
#   inflating: train/Dog/1006.jpg
#   inflating: train/Dog/1007.jpg
#   inflating: train/Dog/1008.jpg
#   inflating: train/Dog/1009.jpg
#   inflating: train/Dog/1010.jpg
#   inflating: train/Dog/1011.jpg
#   inflating: train/Dog/1012.jpg
#   inflating: train/Dog/1013.jpg
#   inflating: train/Dog/1014.jpg
#   inflating: train/Dog/1015.jpg
#   inflating: train/Dog/1016.jpg
#   inflating: train/Dog/1017.jpg
#   inflating: train/Dog/1018.jpg
#   inflating: train/Dog/1019.jpg
#   inflating: train/Dog/1020.jpg
#   inflating: train/Dog/1021.jpg
#   inflating: train/Dog/1022.jpg
#   inflating: train/Dog/1023.jpg
#   inflating: train/Dog/1024.jpg
#   inflating: train/Dog/1025.jpg
#   inflating: train/Dog/1026.jpg
#   inflating: train/Dog/1027.jpg
#   inflating: train/Dog/1028.jpg
#   inflating: train/Dog/1029.jpg
#   inflating: train/Dog/1030.jpg
#   inflating: train/Dog/1031.jpg
#   inflating: train/Dog/1032.jpg
#   inflating: train/Dog/1033.jpg
#   inflating: train/Dog/1034.jpg
#   inflating: train/Dog/1035.jpg
#   inflating: train/Dog/1036.jpg
#   inflating: train/Dog/1037.jpg
#   inflating: train/Dog/1038.jpg
#   inflating: train/Dog/1039.jpg
#   inflating: train/Dog/1040.jpg
#   inflating: train/Dog/1041.jpg
#   inflating: train/Dog/1042.jpg
#   inflating: train/Dog/1043.jpg
#   inflating: train/Dog/1044.jpg
#   inflating: train/Dog/1045.jpg
#   inflating: train/Dog/1046.jpg
#   inflating: train/Dog/1047.jpg
#   inflating: train/Dog/1048.jpg
#   inflating: train/Dog/1049.jpg
#   inflating: train/Dog/1050.jpg
#   inflating: train/Dog/1051.jpg
#   inflating: train/Dog/1052.jpg
#   inflating: train/Dog/1053.jpg
#   inflating: train/Dog/1054.jpg
#   inflating: train/Dog/1055.jpg
#   inflating: train/Dog/1056.jpg
#   inflating: train/Dog/1057.jpg
#   inflating: train/Dog/1058.jpg
#   inflating: train/Dog/1059.jpg
#   inflating: train/Dog/1060.jpg
#   inflating: train/Dog/1061.jpg
#   inflating: train/Dog/1062.jpg
#   inflating: train/Dog/1063.jpg
#   inflating: train/Dog/1064.jpg
#   inflating: train/Dog/1065.jpg
#   inflating: train/Dog/1066.jpg
#   inflating: train/Dog/1067.jpg
#   inflating: train/Dog/1068.jpg
#   inflating: train/Dog/1069.jpg
#   inflating: train/Dog/1070.jpg
#   inflating: train/Dog/11.jpg
#   inflating: train/Dog/12.jpg
#   inflating: train/Dog/13.jpg
#   inflating: train/Dog/14.jpg
#   inflating: train/Dog/15.jpg
#   inflating: train/Dog/16.jpg
#   inflating: train/Dog/17.jpg
#   inflating: train/Dog/18.jpg
#   inflating: train/Dog/19.jpg
#   inflating: train/Dog/2.jpg
#   inflating: train/Dog/20.jpg
#   inflating: train/Dog/21.jpg
#   inflating: train/Dog/22.jpg
#   inflating: train/Dog/23.jpg
#   inflating: train/Dog/24.jpg
#   inflating: train/Dog/25.jpg
#   inflating: train/Dog/26.jpg
#   inflating: train/Dog/27.jpg
#   inflating: train/Dog/28.jpg
#   inflating: train/Dog/29.jpg
#   inflating: train/Dog/3.jpg
#   inflating: train/Dog/30.jpg
#   inflating: train/Dog/31.jpg
#   inflating: train/Dog/32.jpg
#   inflating: train/Dog/33.jpg
#   inflating: train/Dog/34.jpg
#   inflating: train/Dog/35.jpg
#   inflating: train/Dog/36.jpg
#   inflating: train/Dog/37.jpg
#   inflating: train/Dog/38.jpg
#   inflating: train/Dog/39.jpg
#   inflating: train/Dog/4.jpg
#   inflating: train/Dog/40.jpg
#   inflating: train/Dog/41.jpg
#   inflating: train/Dog/42.jpg
#   inflating: train/Dog/43.jpg
#   inflating: train/Dog/44.jpg
#   inflating: train/Dog/45.jpg
#   inflating: train/Dog/46.jpg
#   inflating: train/Dog/47.jpg
#   inflating: train/Dog/48.jpg
#   inflating: train/Dog/49.jpg
#   inflating: train/Dog/5.jpg
#   inflating: train/Dog/50.jpg
#   inflating: train/Dog/51.jpg
#   inflating: train/Dog/52.jpg
#   inflating: train/Dog/53.jpg
#   inflating: train/Dog/54.jpg
#   inflating: train/Dog/55.jpg
#   inflating: train/Dog/56.jpg
#   inflating: train/Dog/57.jpg
#   inflating: train/Dog/58.jpg
#   inflating: train/Dog/59.jpg
#   inflating: train/Dog/6.jpg
#   inflating: train/Dog/60.jpg
#   inflating: train/Dog/61.jpg
#   inflating: train/Dog/62.jpg
#   inflating: train/Dog/7.jpg
#   inflating: train/Dog/8.jpg
#   inflating: train/Dog/9.jpg
#   inflating: train/Dog/931.jpg
#   inflating: train/Dog/932.jpg
#   inflating: train/Dog/933.jpg
#   inflating: train/Dog/934.jpg
#   inflating: train/Dog/935.jpg
#   inflating: train/Dog/936.jpg
#   inflating: train/Dog/937.jpg
#   inflating: train/Dog/938.jpg
#   inflating: train/Dog/939.jpg
#   inflating: train/Dog/940.jpg
#   inflating: train/Dog/941.jpg
#   inflating: train/Dog/942.jpg
#   inflating: train/Dog/943.jpg
#   inflating: train/Dog/944.jpg
#   inflating: train/Dog/945.jpg
#   inflating: train/Dog/946.jpg
#   inflating: train/Dog/947.jpg
#   inflating: train/Dog/948.jpg
#   inflating: train/Dog/949.jpg
#   inflating: train/Dog/950.jpg
#   inflating: train/Dog/951.jpg
#   inflating: train/Dog/952.jpg
#   inflating: train/Dog/953.jpg
#   inflating: train/Dog/954.jpg
#   inflating: train/Dog/955.jpg
#   inflating: train/Dog/956.jpg
#   inflating: train/Dog/957.jpg
#   inflating: train/Dog/958.jpg
#   inflating: train/Dog/959.jpg
#   inflating: train/Dog/960.jpg
#   inflating: train/Dog/961.jpg
#   inflating: train/Dog/962.jpg
#   inflating: train/Dog/963.jpg
#   inflating: train/Dog/964.jpg
#   inflating: train/Dog/965.jpg
#   inflating: train/Dog/966.jpg
#   inflating: train/Dog/967.jpg
#   inflating: train/Dog/968.jpg
#   inflating: train/Dog/969.jpg
#   inflating: train/Dog/970.jpg
#   inflating: train/Dog/971.jpg
#   inflating: train/Dog/972.jpg
#   inflating: train/Dog/973.jpg
#   inflating: train/Dog/974.jpg
#   inflating: train/Dog/975.jpg
#   inflating: train/Dog/976.jpg
#   inflating: train/Dog/977.jpg
#   inflating: train/Dog/978.jpg
#   inflating: train/Dog/979.jpg
#   inflating: train/Dog/980.jpg
#   inflating: train/Dog/981.jpg
#   inflating: train/Dog/982.jpg
#   inflating: train/Dog/983.jpg
#   inflating: train/Dog/984.jpg
#   inflating: train/Dog/985.jpg
#   inflating: train/Dog/986.jpg
#   inflating: train/Dog/987.jpg
#   inflating: train/Dog/988.jpg
#   inflating: train/Dog/989.jpg
#   inflating: train/Dog/990.jpg
#   inflating: train/Dog/991.jpg
#   inflating: train/Dog/992.jpg
#   inflating: train/Dog/993.jpg
#   inflating: train/Dog/994.jpg
#   inflating: train/Dog/995.jpg
#   inflating: train/Dog/996.jpg
#   inflating: train/Dog/997.jpg
#   inflating: train/Dog/998.jpg
#   inflating: train/Dog/999.jpg
#    creating: validation/
#    creating: validation/Cat/
#   inflating: validation/Cat/8100.jpg
#   inflating: validation/Cat/8101.jpg
#   inflating: validation/Cat/8102.jpg
#   inflating: validation/Cat/8103.jpg
#   inflating: validation/Cat/8104.jpg
#   inflating: validation/Cat/8105.jpg
#   inflating: validation/Cat/8106.jpg
#   inflating: validation/Cat/8107.jpg
#   inflating: validation/Cat/8108.jpg
#   inflating: validation/Cat/8109.jpg
#   inflating: validation/Cat/8110.jpg
#   inflating: validation/Cat/8111.jpg
#   inflating: validation/Cat/8112.jpg
#   inflating: validation/Cat/8113.jpg
#   inflating: validation/Cat/8114.jpg
#   inflating: validation/Cat/8115.jpg
#   inflating: validation/Cat/8116.jpg
#   inflating: validation/Cat/8117.jpg
#   inflating: validation/Cat/8118.jpg
#   inflating: validation/Cat/8119.jpg
#   inflating: validation/Cat/8120.jpg
#   inflating: validation/Cat/8121.jpg
#   inflating: validation/Cat/8122.jpg
#   inflating: validation/Cat/8123.jpg
#   inflating: validation/Cat/8124.jpg
#   inflating: validation/Cat/8125.jpg
#   inflating: validation/Cat/8126.jpg
#   inflating: validation/Cat/8127.jpg
#   inflating: validation/Cat/8128.jpg
#   inflating: validation/Cat/8129.jpg
#   inflating: validation/Cat/8130.jpg
#   inflating: validation/Cat/8131.jpg
#   inflating: validation/Cat/8132.jpg
#   inflating: validation/Cat/8133.jpg
#   inflating: validation/Cat/8134.jpg
#   inflating: validation/Cat/8135.jpg
#   inflating: validation/Cat/8136.jpg
#   inflating: validation/Cat/8137.jpg
#   inflating: validation/Cat/8138.jpg
#   inflating: validation/Cat/8139.jpg
#   inflating: validation/Cat/8140.jpg
#   inflating: validation/Cat/8141.jpg
#   inflating: validation/Cat/8142.jpg
#   inflating: validation/Cat/8143.jpg
#   inflating: validation/Cat/8144.jpg
#   inflating: validation/Cat/8145.jpg
#   inflating: validation/Cat/8146.jpg
#   inflating: validation/Cat/8147.jpg
#   inflating: validation/Cat/8148.jpg
#    creating: validation/Dog/
#   inflating: validation/Dog/8100.jpg
#   inflating: validation/Dog/8101.jpg
#   inflating: validation/Dog/8102.jpg
#   inflating: validation/Dog/8103.jpg
#   inflating: validation/Dog/8104.jpg
#   inflating: validation/Dog/8105.jpg
#   inflating: validation/Dog/8106.jpg
#   inflating: validation/Dog/8107.jpg
#   inflating: validation/Dog/8108.jpg
#   inflating: validation/Dog/8109.jpg
#   inflating: validation/Dog/8110.jpg
#   inflating: validation/Dog/8111.jpg
#   inflating: validation/Dog/8112.jpg
#   inflating: validation/Dog/8113.jpg
#   inflating: validation/Dog/8114.jpg
#   inflating: validation/Dog/8115.jpg
#   inflating: validation/Dog/8116.jpg
#   inflating: validation/Dog/8117.jpg
#   inflating: validation/Dog/8118.jpg
#   inflating: validation/Dog/8119.jpg
#   inflating: validation/Dog/8120.jpg
#   inflating: validation/Dog/8121.jpg
#   inflating: validation/Dog/8122.jpg
#   inflating: validation/Dog/8123.jpg
#   inflating: validation/Dog/8124.jpg
#   inflating: validation/Dog/8125.jpg
#   inflating: validation/Dog/8126.jpg
#   inflating: validation/Dog/8127.jpg
#   inflating: validation/Dog/8128.jpg
#   inflating: validation/Dog/8129.jpg
#   inflating: validation/Dog/8130.jpg
#   inflating: validation/Dog/8131.jpg
#   inflating: validation/Dog/8132.jpg
#   inflating: validation/Dog/8133.jpg
#   inflating: validation/Dog/8134.jpg
#   inflating: validation/Dog/8135.jpg
#   inflating: validation/Dog/8136.jpg
#   inflating: validation/Dog/8137.jpg
#   inflating: validation/Dog/8138.jpg
#   inflating: validation/Dog/8139.jpg
#   inflating: validation/Dog/8140.jpg
#   inflating: validation/Dog/8141.jpg
#   inflating: validation/Dog/8142.jpg
#   inflating: validation/Dog/8143.jpg
#   inflating: validation/Dog/8144.jpg
#   inflating: validation/Dog/8145.jpg
#   inflating: validation/Dog/8146.jpg
#   inflating: validation/Dog/8147.jpg
#   inflating: validation/Dog/8148.jpg

# %%
EPOCHS = 100
BATCH_SIZE = 32
image_height = 100
image_width = 100
train_dir = "train/"         #데이터셋이 있는 폴더의 위치입니다.
valid_dir = "validation/"    #데이터셋이 있는 폴더의 위치입니다.

# %%
train = ImageDataGenerator(
                  rescale=1./255,
                  rotation_range=10,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  shear_range=0.1,
                  zoom_range=0.1)

train_generator = train.flow_from_directory(train_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=1,
                                                    shuffle=True,
                                                    class_mode="categorical")

valid = ImageDataGenerator(rescale=1.0/255.0)
valid_generator = valid.flow_from_directory(valid_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=7,
                                                    shuffle=True,
                                                    class_mode="categorical"
                                                    )
train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.

# %%
log_dir="./log6-1/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 0)

# %%
model.fit(train_generator,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_generator,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=[tensorboard_callback],
                    verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 7s 558ms/step - loss: 1.3435 - accuracy: 0.5026 - val_loss: 0.6906 - val_accuracy: 0.5729
# Epoch 2/100
# 12/12 [==============================] - 6s 520ms/step - loss: 0.6973 - accuracy: 0.4466 - val_loss: 0.6943 - val_accuracy: 0.4375
# Epoch 3/100
# 12/12 [==============================] - 6s 521ms/step - loss: 0.6931 - accuracy: 0.5020 - val_loss: 0.6885 - val_accuracy: 0.5208
# Epoch 4/100
# 12/12 [==============================] - 6s 464ms/step - loss: 0.6914 - accuracy: 0.5080 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 5/100
# 12/12 [==============================] - 6s 480ms/step - loss: 0.6875 - accuracy: 0.5608 - val_loss: 0.7219 - val_accuracy: 0.4792
# Epoch 6/100
# 12/12 [==============================] - 6s 465ms/step - loss: 0.6767 - accuracy: 0.5536 - val_loss: 0.6841 - val_accuracy: 0.5833
# Epoch 7/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.6688 - accuracy: 0.6282 - val_loss: 0.6870 - val_accuracy: 0.5104
# Epoch 8/100
# 12/12 [==============================] - 6s 489ms/step - loss: 0.6678 - accuracy: 0.5822 - val_loss: 0.6770 - val_accuracy: 0.5521
# Epoch 9/100
# 12/12 [==============================] - 6s 467ms/step - loss: 0.6689 - accuracy: 0.5542 - val_loss: 0.6822 - val_accuracy: 0.5312
# Epoch 10/100
# 12/12 [==============================] - 6s 495ms/step - loss: 0.6499 - accuracy: 0.6037 - val_loss: 0.6432 - val_accuracy: 0.5938
# Epoch 11/100
# 12/12 [==============================] - 6s 464ms/step - loss: 0.6305 - accuracy: 0.6639 - val_loss: 0.6672 - val_accuracy: 0.6146
# Epoch 12/100
# 12/12 [==============================] - 6s 467ms/step - loss: 0.6706 - accuracy: 0.6115 - val_loss: 0.6840 - val_accuracy: 0.5312
# Epoch 13/100
# 12/12 [==============================] - 6s 468ms/step - loss: 0.6870 - accuracy: 0.5430 - val_loss: 0.6567 - val_accuracy: 0.5938
# Epoch 14/100
# 12/12 [==============================] - 6s 491ms/step - loss: 0.6505 - accuracy: 0.6395 - val_loss: 0.6478 - val_accuracy: 0.6146
# Epoch 15/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.6329 - accuracy: 0.6450 - val_loss: 0.6557 - val_accuracy: 0.5938
# Epoch 16/100
# 12/12 [==============================] - 6s 467ms/step - loss: 0.6773 - accuracy: 0.6001 - val_loss: 0.6837 - val_accuracy: 0.6042
# Epoch 17/100
# 12/12 [==============================] - 6s 488ms/step - loss: 0.6632 - accuracy: 0.6110 - val_loss: 0.6579 - val_accuracy: 0.6146
# Epoch 18/100
# 12/12 [==============================] - 6s 466ms/step - loss: 0.6167 - accuracy: 0.6924 - val_loss: 0.6673 - val_accuracy: 0.5729
# Epoch 19/100
# 12/12 [==============================] - 6s 495ms/step - loss: 0.6709 - accuracy: 0.5604 - val_loss: 0.6660 - val_accuracy: 0.6354
# Epoch 20/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.6520 - accuracy: 0.6286 - val_loss: 0.7225 - val_accuracy: 0.5625
# Epoch 21/100
# 12/12 [==============================] - 6s 493ms/step - loss: 0.6338 - accuracy: 0.6379 - val_loss: 0.6623 - val_accuracy: 0.6458
# Epoch 22/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.6191 - accuracy: 0.6462 - val_loss: 0.6626 - val_accuracy: 0.5938
# Epoch 23/100
# 12/12 [==============================] - 6s 469ms/step - loss: 0.6476 - accuracy: 0.6778 - val_loss: 0.6459 - val_accuracy: 0.6042
# Epoch 24/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.6321 - accuracy: 0.5919 - val_loss: 0.6422 - val_accuracy: 0.6354
# Epoch 25/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.5917 - accuracy: 0.7094 - val_loss: 0.6274 - val_accuracy: 0.6875
# Epoch 26/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.5864 - accuracy: 0.6833 - val_loss: 0.6356 - val_accuracy: 0.6354
# Epoch 27/100
# 12/12 [==============================] - 6s 469ms/step - loss: 0.5867 - accuracy: 0.7083 - val_loss: 0.8369 - val_accuracy: 0.5417
# Epoch 28/100
# 12/12 [==============================] - 6s 464ms/step - loss: 0.6499 - accuracy: 0.6496 - val_loss: 0.6487 - val_accuracy: 0.6250
# Epoch 29/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.5854 - accuracy: 0.6865 - val_loss: 0.7288 - val_accuracy: 0.5521
# Epoch 30/100
# 12/12 [==============================] - 6s 466ms/step - loss: 0.6059 - accuracy: 0.6703 - val_loss: 0.7285 - val_accuracy: 0.5729
# Epoch 31/100
# 12/12 [==============================] - 6s 482ms/step - loss: 0.5900 - accuracy: 0.6622 - val_loss: 0.6844 - val_accuracy: 0.6042
# Epoch 32/100
# 12/12 [==============================] - 6s 491ms/step - loss: 0.5930 - accuracy: 0.6743 - val_loss: 0.6996 - val_accuracy: 0.5833
# Epoch 33/100
# 12/12 [==============================] - 10s 814ms/step - loss: 0.5781 - accuracy: 0.7055 - val_loss: 0.7031 - val_accuracy: 0.6042
# Epoch 34/100
# 12/12 [==============================] - 7s 551ms/step - loss: 0.5863 - accuracy: 0.6513 - val_loss: 0.6655 - val_accuracy: 0.6042
# Epoch 35/100
# 12/12 [==============================] - 6s 469ms/step - loss: 0.5733 - accuracy: 0.6830 - val_loss: 0.7145 - val_accuracy: 0.5938
# Epoch 36/100
# 12/12 [==============================] - 6s 476ms/step - loss: 0.5863 - accuracy: 0.6955 - val_loss: 0.7113 - val_accuracy: 0.6250
# Epoch 37/100
# 12/12 [==============================] - 6s 468ms/step - loss: 0.5270 - accuracy: 0.7663 - val_loss: 0.7123 - val_accuracy: 0.6354
# Epoch 38/100
# 12/12 [==============================] - 6s 466ms/step - loss: 0.5052 - accuracy: 0.7652 - val_loss: 0.7476 - val_accuracy: 0.6250
# Epoch 39/100
# 12/12 [==============================] - 6s 469ms/step - loss: 0.4881 - accuracy: 0.7543 - val_loss: 0.7084 - val_accuracy: 0.5938
# Epoch 40/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.5367 - accuracy: 0.7344 - val_loss: 0.7192 - val_accuracy: 0.5312
# Epoch 41/100
# 12/12 [==============================] - 6s 466ms/step - loss: 0.5698 - accuracy: 0.6688 - val_loss: 0.7664 - val_accuracy: 0.5729
# Epoch 42/100
# 12/12 [==============================] - 6s 467ms/step - loss: 0.5066 - accuracy: 0.7366 - val_loss: 0.7126 - val_accuracy: 0.5833
# Epoch 43/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.5208 - accuracy: 0.7789 - val_loss: 0.7024 - val_accuracy: 0.5729
# Epoch 44/100
# 12/12 [==============================] - 6s 469ms/step - loss: 0.5145 - accuracy: 0.7650 - val_loss: 0.7488 - val_accuracy: 0.5938
# Epoch 45/100
# 12/12 [==============================] - 6s 468ms/step - loss: 0.5346 - accuracy: 0.7451 - val_loss: 0.6712 - val_accuracy: 0.6562
# Epoch 46/100
# 12/12 [==============================] - 6s 469ms/step - loss: 0.4578 - accuracy: 0.7871 - val_loss: 0.7295 - val_accuracy: 0.6458
# Epoch 47/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.5750 - accuracy: 0.6923 - val_loss: 0.6792 - val_accuracy: 0.5938
# Epoch 48/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.4840 - accuracy: 0.7537 - val_loss: 0.6904 - val_accuracy: 0.6042
# Epoch 49/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.4592 - accuracy: 0.7855 - val_loss: 0.6933 - val_accuracy: 0.6146
# Epoch 50/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.4272 - accuracy: 0.7924 - val_loss: 0.7499 - val_accuracy: 0.6354
# Epoch 51/100
# 12/12 [==============================] - 6s 494ms/step - loss: 0.4691 - accuracy: 0.7742 - val_loss: 0.7610 - val_accuracy: 0.5938
# Epoch 52/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.3957 - accuracy: 0.8222 - val_loss: 0.8061 - val_accuracy: 0.5729
# Epoch 53/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.4436 - accuracy: 0.7892 - val_loss: 0.7965 - val_accuracy: 0.5833
# Epoch 54/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.4335 - accuracy: 0.8031 - val_loss: 0.8071 - val_accuracy: 0.6354
# Epoch 55/100
# 12/12 [==============================] - 6s 523ms/step - loss: 0.4334 - accuracy: 0.8079 - val_loss: 0.7922 - val_accuracy: 0.6042
# Epoch 56/100
# 12/12 [==============================] - 6s 474ms/step - loss: 0.4593 - accuracy: 0.7767 - val_loss: 0.6880 - val_accuracy: 0.6979
# Epoch 57/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.4408 - accuracy: 0.7609 - val_loss: 0.7176 - val_accuracy: 0.6354
# Epoch 58/100
# 12/12 [==============================] - 6s 468ms/step - loss: 0.3692 - accuracy: 0.8337 - val_loss: 0.7785 - val_accuracy: 0.6562
# Epoch 59/100
# 12/12 [==============================] - 6s 499ms/step - loss: 0.4077 - accuracy: 0.7989 - val_loss: 0.7488 - val_accuracy: 0.6146
# Epoch 60/100
# 12/12 [==============================] - 6s 474ms/step - loss: 0.3906 - accuracy: 0.8108 - val_loss: 0.8502 - val_accuracy: 0.6250
# Epoch 61/100
# 12/12 [==============================] - 6s 525ms/step - loss: 0.2835 - accuracy: 0.8701 - val_loss: 0.8731 - val_accuracy: 0.6250
# Epoch 62/100
# 12/12 [==============================] - 6s 468ms/step - loss: 0.3520 - accuracy: 0.8993 - val_loss: 0.9034 - val_accuracy: 0.6458
# Epoch 63/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.3608 - accuracy: 0.8558 - val_loss: 0.8536 - val_accuracy: 0.6667
# Epoch 64/100
# 12/12 [==============================] - 6s 470ms/step - loss: 0.3262 - accuracy: 0.8537 - val_loss: 0.9183 - val_accuracy: 0.6667
# Epoch 65/100
# 12/12 [==============================] - 6s 491ms/step - loss: 0.3372 - accuracy: 0.8284 - val_loss: 0.8318 - val_accuracy: 0.6250
# Epoch 66/100
# 12/12 [==============================] - 6s 500ms/step - loss: 0.3285 - accuracy: 0.8478 - val_loss: 0.9244 - val_accuracy: 0.6250
# Epoch 67/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.2711 - accuracy: 0.8829 - val_loss: 0.8942 - val_accuracy: 0.6354
# Epoch 68/100
# 12/12 [==============================] - 6s 466ms/step - loss: 0.3209 - accuracy: 0.8435 - val_loss: 0.9178 - val_accuracy: 0.6458
# Epoch 69/100
# 12/12 [==============================] - 6s 497ms/step - loss: 0.3458 - accuracy: 0.8339 - val_loss: 0.8044 - val_accuracy: 0.6875
# Epoch 70/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.3702 - accuracy: 0.8350 - val_loss: 0.8135 - val_accuracy: 0.6562
# Epoch 71/100
# 12/12 [==============================] - 6s 466ms/step - loss: 0.3386 - accuracy: 0.8634 - val_loss: 0.8216 - val_accuracy: 0.6562
# Epoch 72/100
# 12/12 [==============================] - 6s 523ms/step - loss: 0.2673 - accuracy: 0.8824 - val_loss: 0.8565 - val_accuracy: 0.6458
# Epoch 73/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.2857 - accuracy: 0.8789 - val_loss: 0.9218 - val_accuracy: 0.6042
# Epoch 74/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.4210 - accuracy: 0.7991 - val_loss: 0.9250 - val_accuracy: 0.5938
# Epoch 75/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.3795 - accuracy: 0.8267 - val_loss: 0.7993 - val_accuracy: 0.6875
# Epoch 76/100
# 12/12 [==============================] - 6s 474ms/step - loss: 0.2950 - accuracy: 0.8675 - val_loss: 0.9812 - val_accuracy: 0.6250
# Epoch 77/100
# 12/12 [==============================] - 6s 474ms/step - loss: 0.2960 - accuracy: 0.8535 - val_loss: 0.9939 - val_accuracy: 0.6562
# Epoch 78/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.3451 - accuracy: 0.8443 - val_loss: 0.7944 - val_accuracy: 0.6875
# Epoch 79/100
# 12/12 [==============================] - 6s 478ms/step - loss: 0.2932 - accuracy: 0.8875 - val_loss: 0.8324 - val_accuracy: 0.6667
# Epoch 80/100
# 12/12 [==============================] - 6s 478ms/step - loss: 0.3078 - accuracy: 0.8317 - val_loss: 0.8390 - val_accuracy: 0.7083
# Epoch 81/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.2016 - accuracy: 0.9246 - val_loss: 0.9565 - val_accuracy: 0.6562
# Epoch 82/100
# 12/12 [==============================] - 6s 487ms/step - loss: 0.2600 - accuracy: 0.8780 - val_loss: 0.9162 - val_accuracy: 0.6458
# Epoch 83/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.2183 - accuracy: 0.9179 - val_loss: 1.2378 - val_accuracy: 0.6667
# Epoch 84/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.2523 - accuracy: 0.9064 - val_loss: 1.1717 - val_accuracy: 0.6146
# Epoch 85/100
# 12/12 [==============================] - 6s 475ms/step - loss: 0.2865 - accuracy: 0.9050 - val_loss: 1.1015 - val_accuracy: 0.6562
# Epoch 86/100
# 12/12 [==============================] - 6s 474ms/step - loss: 0.1679 - accuracy: 0.9334 - val_loss: 1.0165 - val_accuracy: 0.6979
# Epoch 87/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.2716 - accuracy: 0.8933 - val_loss: 1.3501 - val_accuracy: 0.6771
# Epoch 88/100
# 12/12 [==============================] - 6s 475ms/step - loss: 0.4671 - accuracy: 0.8140 - val_loss: 1.0237 - val_accuracy: 0.5938
# Epoch 89/100
# 12/12 [==============================] - 6s 475ms/step - loss: 0.3751 - accuracy: 0.8294 - val_loss: 0.8511 - val_accuracy: 0.6042
# Epoch 90/100
# 12/12 [==============================] - 6s 472ms/step - loss: 0.3639 - accuracy: 0.8508 - val_loss: 0.9079 - val_accuracy: 0.5417
# Epoch 91/100
# 12/12 [==============================] - 6s 497ms/step - loss: 0.3396 - accuracy: 0.8593 - val_loss: 1.0343 - val_accuracy: 0.5625
# Epoch 92/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.3116 - accuracy: 0.8673 - val_loss: 1.1316 - val_accuracy: 0.5833
# Epoch 93/100
# 12/12 [==============================] - 6s 475ms/step - loss: 0.2256 - accuracy: 0.9225 - val_loss: 1.1742 - val_accuracy: 0.6146
# Epoch 94/100
# 12/12 [==============================] - 6s 484ms/step - loss: 0.2055 - accuracy: 0.9144 - val_loss: 1.1941 - val_accuracy: 0.6667
# Epoch 95/100
# 12/12 [==============================] - 6s 489ms/step - loss: 0.1754 - accuracy: 0.9203 - val_loss: 0.9840 - val_accuracy: 0.6458
# Epoch 96/100
# 12/12 [==============================] - 6s 473ms/step - loss: 0.2178 - accuracy: 0.9110 - val_loss: 1.0803 - val_accuracy: 0.6562
# Epoch 97/100
# 12/12 [==============================] - 6s 477ms/step - loss: 0.1772 - accuracy: 0.9180 - val_loss: 1.2441 - val_accuracy: 0.6354
# Epoch 98/100
# 12/12 [==============================] - 6s 475ms/step - loss: 0.2277 - accuracy: 0.9006 - val_loss: 1.5514 - val_accuracy: 0.5833
# Epoch 99/100
# 12/12 [==============================] - 6s 471ms/step - loss: 0.4443 - accuracy: 0.8384 - val_loss: 0.8582 - val_accuracy: 0.6042
# Epoch 100/100
# 12/12 [==============================] - 6s 474ms/step - loss: 0.2781 - accuracy: 0.8717 - val_loss: 0.9610 - val_accuracy: 0.6250

# %%
class_names = ['cat', 'dog']
validation, label_batch  = next(iter(valid_generator))
prediction_values = model.predict(validation)
prediction_values = np.argmax(prediction_values, axis=1)

fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(8):
    ax = fig.add_subplot(2, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(validation[i,:],cmap=plt.cm.gray_r, interpolation='nearest')
      
    if prediction_values[i] == np.argmax(label_batch[i]):
        ax.text(3, 17, class_names[prediction_values[i]], color='yellow', fontsize=14)
    else:
        ax.text(3, 17, class_names[prediction_values[i]], color='red', fontsize=14)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#6.1.3 AlexNet

# %%
# %load_ext tensorboard

import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
num_classes = 2
class AlexNet(Sequential):
    def __init__(self, input_shape, num_classes):
        super().__init__()

        self.add(Conv2D(96, kernel_size=(11,11), strides= 4,
                        padding= 'valid', activation= 'relu',
                        input_shape= input_shape,
                        kernel_initializer= 'he_normal'))
        self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None))

        self.add(Conv2D(256, kernel_size=(5,5), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
        self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None)) 

        self.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))
        self.add(Conv2D(384, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))

        self.add(Conv2D(256, kernel_size=(3,3), strides= 1,
                        padding= 'same', activation= 'relu',
                        kernel_initializer= 'he_normal'))

        self.add(MaxPooling2D(pool_size=(3,3), strides= (2,2),
                              padding= 'valid', data_format= None))

        self.add(Flatten())
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dense(1000, activation= 'relu'))
        self.add(Dense(num_classes, activation= 'softmax'))

        self.compile(optimizer= tf.keras.optimizers.Adam(0.001),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %%
model = AlexNet((100, 100, 3), num_classes)
model.summary()
# Out:
# Model: "alex_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 23, 23, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 11, 11, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 384)         885120
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 384)         1327488
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 256)         884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              4198400
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 2002
# =================================================================
# Total params: 28,825,914
# Trainable params: 28,825,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE = 32
image_height = 100
image_width = 100
train_dir = "train"
valid_dir = "validation"

# %%
train = ImageDataGenerator(
                  rescale=1./255,
                  rotation_range=10,
                  width_shift_range=0.1,
                  height_shift_range=0.1,
                  shear_range=0.1,
                  zoom_range=0.1)

train_generator = train.flow_from_directory(train_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=1,
                                                    shuffle=True,
                                                    class_mode="categorical")

valid = ImageDataGenerator(rescale=1.0/255.0)
valid_generator = valid.flow_from_directory(valid_dir,
                                                    target_size=(image_height, image_width),
                                                    color_mode="rgb",
                                                    batch_size=BATCH_SIZE,
                                                    seed=7,
                                                    shuffle=True,
                                                    class_mode="categorical"
                                                    )
train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.

# %%
log_dir="./log6-2/"
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 0)

# %%
model.fit(train_generator,
                    epochs=EPOCHS,
                    steps_per_epoch=train_num // BATCH_SIZE,
                    validation_data=valid_generator,
                    validation_steps=valid_num // BATCH_SIZE,
                    callbacks=[tensorboard_callback],
                    verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 16s 1s/step - loss: 25.2131 - accuracy: 0.5820 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 2/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.7073 - accuracy: 0.4504 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6947 - accuracy: 0.5203 - val_loss: 0.7136 - val_accuracy: 0.4896
# Epoch 4/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6969 - accuracy: 0.5403 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 5/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6921 - accuracy: 0.5282 - val_loss: 0.6936 - val_accuracy: 0.4479
# Epoch 6/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6934 - accuracy: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5104
# Epoch 7/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6943 - accuracy: 0.4945 - val_loss: 0.6946 - val_accuracy: 0.4896
# Epoch 8/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6929 - accuracy: 0.5171 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 9/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6922 - accuracy: 0.5234 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 10/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6941 - accuracy: 0.4993 - val_loss: 0.6943 - val_accuracy: 0.5208
# Epoch 11/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6986 - accuracy: 0.4993 - val_loss: 0.6973 - val_accuracy: 0.4896
# Epoch 12/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6938 - accuracy: 0.5046 - val_loss: 0.6893 - val_accuracy: 0.5208
# Epoch 13/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6913 - accuracy: 0.5347 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6934 - accuracy: 0.4800 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 15/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6937 - accuracy: 0.4802 - val_loss: 0.6938 - val_accuracy: 0.4896
# Epoch 16/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6924 - accuracy: 0.5155 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 17/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6902 - accuracy: 0.5561 - val_loss: 0.6953 - val_accuracy: 0.4896
# Epoch 18/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6894 - accuracy: 0.5496 - val_loss: 0.6940 - val_accuracy: 0.5000
# Epoch 19/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6962 - accuracy: 0.4773 - val_loss: 0.6929 - val_accuracy: 0.5104
# Epoch 20/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6925 - accuracy: 0.5192 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 21/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6918 - accuracy: 0.5278 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 22/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6902 - accuracy: 0.5529 - val_loss: 0.6932 - val_accuracy: 0.5104
# Epoch 23/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6950 - accuracy: 0.4947 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 24/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6913 - accuracy: 0.5347 - val_loss: 0.6943 - val_accuracy: 0.4896
# Epoch 25/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6911 - accuracy: 0.5378 - val_loss: 0.6928 - val_accuracy: 0.5104
# Epoch 26/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6909 - accuracy: 0.5462 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 27/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6923 - accuracy: 0.5238 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 28/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6879 - accuracy: 0.5774 - val_loss: 0.6911 - val_accuracy: 0.5000
# Epoch 29/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6879 - accuracy: 0.5463 - val_loss: 0.7422 - val_accuracy: 0.5104
# Epoch 30/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.7223 - accuracy: 0.5514 - val_loss: 0.6997 - val_accuracy: 0.4896
# Epoch 31/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.7122 - accuracy: 0.5391 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 32/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6930 - accuracy: 0.5108 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 33/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6914 - accuracy: 0.5402 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 34/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6922 - accuracy: 0.5445 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 35/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6921 - accuracy: 0.5456 - val_loss: 0.6935 - val_accuracy: 0.4896
# Epoch 36/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6923 - accuracy: 0.5285 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 37/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6912 - accuracy: 0.5379 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 38/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6871 - accuracy: 0.5968 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 39/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6927 - accuracy: 0.5109 - val_loss: 0.6945 - val_accuracy: 0.4896
# Epoch 40/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6918 - accuracy: 0.5284 - val_loss: 0.6950 - val_accuracy: 0.4896
# Epoch 41/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6953 - accuracy: 0.4866 - val_loss: 0.6939 - val_accuracy: 0.5000
# Epoch 42/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6928 - accuracy: 0.5149 - val_loss: 0.6931 - val_accuracy: 0.5104
# Epoch 43/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6904 - accuracy: 0.5435 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 44/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6887 - accuracy: 0.5688 - val_loss: 0.6938 - val_accuracy: 0.4896
# Epoch 45/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.7065 - accuracy: 0.4878 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 46/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6928 - accuracy: 0.5219 - val_loss: 0.6945 - val_accuracy: 0.5000
# Epoch 47/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6888 - accuracy: 0.5632 - val_loss: 0.6983 - val_accuracy: 0.5000
# Epoch 48/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6951 - accuracy: 0.5158 - val_loss: 0.6972 - val_accuracy: 0.5000
# Epoch 49/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6996 - accuracy: 0.4886 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 50/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6928 - accuracy: 0.5204 - val_loss: 0.6929 - val_accuracy: 0.4792
# Epoch 51/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6925 - accuracy: 0.5466 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 52/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6938 - accuracy: 0.4593 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 53/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6933 - accuracy: 0.4955 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 54/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6936 - accuracy: 0.4947 - val_loss: 0.6943 - val_accuracy: 0.4896
# Epoch 55/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6947 - accuracy: 0.4817 - val_loss: 0.6945 - val_accuracy: 0.5000
# Epoch 56/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6931 - accuracy: 0.5144 - val_loss: 0.6946 - val_accuracy: 0.5000
# Epoch 57/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6934 - accuracy: 0.5113 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 58/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6908 - accuracy: 0.5394 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 59/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6918 - accuracy: 0.5284 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 60/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6906 - accuracy: 0.5459 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 61/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6933 - accuracy: 0.5098 - val_loss: 0.6951 - val_accuracy: 0.4896
# Epoch 62/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6893 - accuracy: 0.5549 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 63/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6927 - accuracy: 0.5160 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 64/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6918 - accuracy: 0.5296 - val_loss: 0.6930 - val_accuracy: 0.5104
# Epoch 65/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6921 - accuracy: 0.5243 - val_loss: 0.6947 - val_accuracy: 0.4896
# Epoch 66/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6932 - accuracy: 0.5074 - val_loss: 0.6946 - val_accuracy: 0.5000
# Epoch 67/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6941 - accuracy: 0.5036 - val_loss: 0.6961 - val_accuracy: 0.5000
# Epoch 68/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6892 - accuracy: 0.5399 - val_loss: 0.7068 - val_accuracy: 0.5000
# Epoch 69/100
# 12/12 [==============================] - 15s 1s/step - loss: 1.1527 - accuracy: 0.5611 - val_loss: 0.6947 - val_accuracy: 0.5000
# Epoch 70/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6917 - accuracy: 0.5642 - val_loss: 0.6954 - val_accuracy: 0.4375
# Epoch 71/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6945 - accuracy: 0.4533 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 72/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6947 - accuracy: 0.5016 - val_loss: 0.6930 - val_accuracy: 0.4896
# Epoch 73/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6956 - accuracy: 0.4983 - val_loss: 0.6939 - val_accuracy: 0.5312
# Epoch 74/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6934 - accuracy: 0.5446 - val_loss: 0.6950 - val_accuracy: 0.5104
# Epoch 75/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6903 - accuracy: 0.5379 - val_loss: 0.7233 - val_accuracy: 0.5000
# Epoch 76/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7042 - accuracy: 0.5002 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 77/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6959 - accuracy: 0.5459 - val_loss: 0.6941 - val_accuracy: 0.5312
# Epoch 78/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6931 - accuracy: 0.5214 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 79/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6936 - accuracy: 0.4982 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 80/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6968 - accuracy: 0.5483 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 81/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6929 - accuracy: 0.5206 - val_loss: 0.6943 - val_accuracy: 0.4896
# Epoch 82/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6915 - accuracy: 0.5358 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 83/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6935 - accuracy: 0.5159 - val_loss: 0.6939 - val_accuracy: 0.5000
# Epoch 84/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6913 - accuracy: 0.5347 - val_loss: 0.6937 - val_accuracy: 0.5104
# Epoch 85/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6910 - accuracy: 0.5343 - val_loss: 0.6949 - val_accuracy: 0.5104
# Epoch 86/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6940 - accuracy: 0.5131 - val_loss: 0.6964 - val_accuracy: 0.4896
# Epoch 87/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6895 - accuracy: 0.5447 - val_loss: 0.6950 - val_accuracy: 0.4896
# Epoch 88/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6913 - accuracy: 0.5326 - val_loss: 0.6941 - val_accuracy: 0.5000
# Epoch 89/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6923 - accuracy: 0.5230 - val_loss: 0.6932 - val_accuracy: 0.5104
# Epoch 90/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6921 - accuracy: 0.5246 - val_loss: 0.6941 - val_accuracy: 0.4896
# Epoch 91/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6887 - accuracy: 0.5838 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 92/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6945 - accuracy: 0.4892 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 93/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6923 - accuracy: 0.5260 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 94/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6922 - accuracy: 0.5268 - val_loss: 0.6923 - val_accuracy: 0.5104
# Epoch 95/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6916 - accuracy: 0.4950 - val_loss: 0.6954 - val_accuracy: 0.4896
# Epoch 96/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6915 - accuracy: 0.4948 - val_loss: 0.6920 - val_accuracy: 0.5000
# Epoch 97/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6876 - accuracy: 0.5155 - val_loss: 0.6932 - val_accuracy: 0.4896
# Epoch 98/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6927 - accuracy: 0.5600 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 99/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6938 - accuracy: 0.4965 - val_loss: 0.6960 - val_accuracy: 0.4896
# Epoch 100/100
# 12/12 [==============================] - 15s 1s/step - loss: 0.6999 - accuracy: 0.4886 - val_loss: 0.6931 - val_accuracy: 0.5104

# %%
class_names = ['cat', 'dog']
validation, label_batch  = next(iter(valid_generator))
prediction_values = model.predict(validation)
prediction_values = np.argmax(prediction_values, axis=1)

fig = plt.figure(figsize=(12, 8))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(8):
    ax = fig.add_subplot(2, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(validation[i,:],cmap=plt.cm.gray_r, interpolation='nearest')
  
    if prediction_values[i] == np.argmax(label_batch[i]):
        ax.text(3, 17, class_names[prediction_values[i]], color='yellow', fontsize=14)
    else:
        ax.text(3, 17, class_names[prediction_values[i]], color='red', fontsize=14)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#6.1.4 VGGNet

# %%
#pip install opencv-python
# %load_ext tensorboard

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2

from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
class VGG19(Sequential):
    def __init__(self, input_shape):
        super().__init__()

        self.add(Conv2D(64, kernel_size=(3,3), padding= 'same',
                        activation= 'relu', input_shape= input_shape))
        self.add(Conv2D(64, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(128, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(128, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(256, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(Conv2D(512, kernel_size=(3,3), padding= 'same',
                        activation= 'relu'))
        self.add(MaxPooling2D(pool_size=(2,2), strides= (2,2)))

        self.add(Flatten())
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dropout(0.5))
        self.add(Dense(4096, activation= 'relu'))
        self.add(Dropout(0.5))
        self.add(Dense(1000, activation= 'softmax'))

        self.compile(optimizer= tf.keras.optimizers.Adam(0.003),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# %%
model = VGG19(input_shape=(224, 224, 3))
model.summary()
# Out:
# Model: "vg_g19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()

model.load_weights("vgg19_weights_tf_dim_ordering_tf_kernels.h5")
# Out:
#      <input type="file" id="files-91ac6ad3-9c30-4b0e-b70a-8a5fde5148ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91ac6ad3-9c30-4b0e-b70a-8a5fde5148ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vgg19_weights_tf_dim_ordering_tf_kernels.h5 to vgg19_weights_tf_dim_ordering_tf_kernels.h5

# %%
classes= {282: 'cat',
 681: 'notebook, notebook computer',
 970: 'alp'}

# %%
from google.colab import files # 데이터 불러오기
file_uploaded=files.upload()

image1=cv2.imread('labtop.jpg')
#image1=cv2.imread('starrynight.jpeg')
#image1=cv2.imread('cat.jpg')
image1 = cv2.resize(image1, (224, 224))
plt.figure()
plt.imshow(image1)
image1 = image1[np.newaxis, :]
predicted_value = model.predict(image1)
predicted_value = np.argmax(predicted_value)
plt.title(classes[predicted_value])
# Out:
#      <input type="file" id="files-6244bac5-6b35-45a1-872d-5702cc1c97d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6244bac5-6b35-45a1-872d-5702cc1c97d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labtop.jpg to labtop.jpg
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Text(0.5, 1.0, 'notebook, notebook computer')

# %%
#6.1.6 ResNset

# %%
def res_identity(x, filters): 
  x_skip = x 
  f1, f2 = filters

  x = Conv2D(f1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)

  x = Add()([x, x_skip])
  x = Activation(activations.relu)(x)

  return x

# %%
def res_conv(x, s, filters):
  x_skip = x
  f1, f2 = filters

  x = Conv2D(f1, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x)
  # when s = 2 then it is like downsizing the feature map
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)

  x_skip = Conv2D(f2, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x_skip)
  x_skip = BatchNormalization()(x_skip)
 
  x = Add()([x, x_skip])
  x = Activation(activations.relu)(x)

  return x
